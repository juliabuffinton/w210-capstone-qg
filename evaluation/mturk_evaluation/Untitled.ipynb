# %%
import csv
import pandas as pd

# %%
mturk_results = pd.read_csv('All_results.csv')
mturk_results.head()
# Out:
#                             HITId                       HITTypeId  \
# 0  3R5LWXWHR08KWZTS2R8W5O8NVGAXGH  3MOP54T9IO9VASG0NDBCNQK89X7Y0M
# 1  3R5LWXWHR08KWZTS2R8W5O8NVGAXGH  3MOP54T9IO9VASG0NDBCNQK89X7Y0M
# 2  3R5LWXWHR08KWZTS2R8W5O8NVGAXGH  3MOP54T9IO9VASG0NDBCNQK89X7Y0M
# 3  3R5LWXWHR08KWZTS2R8W5O8NVGAXGH  3MOP54T9IO9VASG0NDBCNQK89X7Y0M
# 4  3NCN4N1H1GHJTO7DKZT96BQSDP8NB6  3MOP54T9IO9VASG0NDBCNQK89X7Y0M
#
#                             Title  \
# 0  Rate the quality of a question
# 1  Rate the quality of a question
# 2  Rate the quality of a question
# 3  Rate the quality of a question
# 4  Rate the quality of a question
#
#                                          Description  \
# 0  Given a sentence and a corresponding question,...
# 1  Given a sentence and a corresponding question,...
# 2  Given a sentence and a corresponding question,...
# 3  Given a sentence and a corresponding question,...
# 4  Given a sentence and a corresponding question,...
#
# ...

# %%
mturk_results = mturk_results.drop(["Approve","Reject","Title","Description","Keywords","Reward",
                                   "CreationTime","MaxAssignments","RequesterAnnotation","AssignmentDurationInSeconds",
                                   "AutoApprovalDelayInSeconds","Expiration","NumberOfSimilarHITs","LifetimeInSeconds",
                                   "AssignmentStatus","AcceptTime","SubmitTime","AutoApprovalTime", "ApprovalTime",
                                   "RejectionTime","RequesterFeedback","LifetimeApprovalRate","Last30DaysApprovalRate",
                                   "Last7DaysApprovalRate","HITTypeId"],axis=1)

# %%
mturk_results.head()
# Out:
#                             HITId                    AssignmentId  \
# 0  3R5LWXWHR08KWZTS2R8W5O8NVGAXGH  31LVTDXBL7AI7FJBVL5MHIMSTBRRL4
# 1  3R5LWXWHR08KWZTS2R8W5O8NVGAXGH  31T4R4OBOSGFMS5Q9UEH9I55YQI7C4
# 2  3R5LWXWHR08KWZTS2R8W5O8NVGAXGH  3B3WTRP3DB262T1HRYNVB1NPHPV294
# 3  3R5LWXWHR08KWZTS2R8W5O8NVGAXGH  3F0BG9B9MPNSPV6V5MW669XO1E17YD
# 4  3NCN4N1H1GHJTO7DKZT96BQSDP8NB6  32AT8R96GL9XRK6IJOXSYFN7S44USQ
#
#          WorkerId  WorkTimeInSeconds  \
# 0  A2RR3R75ECQSKE                221
# 1  A2SBISQJE2ZPJQ                218
# 2  A15A09BRS1Q8W0                131
# 3  A1NGXQMOBCXDC3                272
# 4  A15A09BRS1Q8W0                182
#
#                                       Input.context1  Input.number1  \
# 0  on the evening of the same day, the couple was...            137
# 1  on the evening of the same day, the couple was...            137
# 2  on the evening of the same day, the couple was...            137
# ...

# %%
for index,row in mturk_results.iterrows():
    mturk_results.append({'HITId' : row['HITId']})
    print(row["HITId"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-d58950776ad0> in <module>()
#       1 for index,row in mturk_results.iterrows():
# ----> 2     mturk_results.append({'HITId' : row['HITId']})
#       3     print(row["HITId"])
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity)
#    5162                 other = Series(other)
#    5163             if other.name is None and not ignore_index:
# -> 5164                 raise TypeError('Can only append a Series if ignore_index=True'
#    5165                                 ' or if the Series has a name')
#    5166
#
# TypeError: Can only append a Series if ignore_index=True or if the Series has a name
